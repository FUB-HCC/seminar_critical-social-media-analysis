# %% [markdown]
# #Introduction
#
# .....

# %% [markdown]
# Check to see if jupyter lab uses the correct python interpreter with '!which python'.
# It should be something like '/opt/anaconda3/envs/[environment name]/bin/python' (on Mac).
# If not, try this: https://github.com/jupyter/notebook/issues/3146#issuecomment-352718675

# %%
# !which python
# Out:
# 'which' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %% [markdown]
# # Install dependencies:

# %%
install_packages = True
if install_packages:
    # !conda install tensorflow=2 -y
    print("tensorflow installed")
    # !conda install -c anaconda pandas -y
    print("pandas installed")
    # !conda install -c conda-forge tensorflow-hub -y
    print("tensorflow-hub installed")
    # !conda install -c akode html2text -y
    print("html2text installed")
    # !conda install -c conda-forge tqdm -y
    print("tqdm installed")
    # !conda install -c anaconda scikit-learn -y
    print("scikit-learn  installed")
    # !conda install -c conda-forge matplotlib -y
    print("matplotlib installed")
    # !conda install -c anaconda seaborn -y
    print("seaborn installed")
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\xinyu\anaconda3\envs\Seminar_csma
#
#   added / updated specs:
#     - tensorflow=2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _tflow_select-2.2.0        |            eigen           3 KB
#     absl-py-0.11.0             |   py36haa95532_0         192 KB
#     aiohttp-3.6.3              |   py36he774522_0         512 KB
#     astor-0.8.1                |           py36_0          47 KB
#     async-timeout-3.0.1        |           py36_0          12 KB
#     blinker-1.4                |           py36_0          22 KB
#     ca-certificates-2020.10.14 |                0         122 KB
#     cachetools-4.1.1           |             py_0          12 KB
#     click-7.1.2                |             py_0          71 KB
#     gast-0.2.2                 |           py36_0         155 KB
#     google-auth-1.23.0         |     pyhd3eb1b0_0          61 KB
#     google-auth-oauthlib-0.4.2 |     pyhd3eb1b0_2          18 KB
#     google-pasta-0.2.0         |             py_0          46 KB
#     grpcio-1.31.0              |   py36he7da953_0         1.5 MB
#     h5py-2.10.0                |   py36h5e291fa_0         807 KB
#     idna_ssl-1.1.0             |           py36_0           7 KB
#     intel-openmp-2020.2        |              254         1.6 MB
#     keras-applications-1.0.8   |             py_1          29 KB
#     keras-preprocessing-1.1.0  |             py_1          37 KB
#     libprotobuf-3.13.0.1       |       h200bbdf_0         1.8 MB
#     markdown-3.3.3             |   py36haa95532_0         143 KB
#     mkl-2020.2                 |              256       109.3 MB
#     mkl-service-2.3.0          |   py36h2bbff1b_0          45 KB
#     mkl_fft-1.2.0              |   py36h45dec08_0         118 KB
#     mkl_random-1.1.1           |   py36h47e9c7a_0         235 KB
#     multidict-4.7.6            |   py36he774522_1          60 KB
#     numpy-1.19.2               |   py36hadc3359_0          22 KB
#     numpy-base-1.19.2          |   py36ha3acd2a_0         3.8 MB
#     oauthlib-3.1.0             |             py_0          91 KB
#     openssl-1.1.1h             |       he774522_0         4.8 MB
#     opt_einsum-3.1.0           |             py_0          54 KB
#     protobuf-3.13.0.1          |   py36ha925a31_1         538 KB
#     pyasn1-0.4.8               |             py_0          57 KB
#     pyasn1-modules-0.2.8       |             py_0          72 KB
#     pyjwt-1.7.1                |           py36_0          49 KB
#     pyreadline-2.1             |           py36_1         143 KB
#     requests-oauthlib-1.3.0    |             py_0          23 KB
#     rsa-4.6                    |             py_0          26 KB
#     scipy-1.5.2                |   py36h9439919_0        11.9 MB
#     tensorboard-2.3.0          |     pyh4dce500_0         5.2 MB
#     tensorboard-plugin-wit-1.6.0|             py_0         630 KB
#     tensorflow-2.1.0           |eigen_py36hdbbabfe_0           4 KB
#     tensorflow-base-2.1.0      |eigen_py36h49b2757_0        35.4 MB
#     tensorflow-estimator-2.1.0 |     pyhd54b08b_0         251 KB
#     termcolor-1.1.0            |           py36_1           9 KB
#     typing_extensions-3.7.4.3  |             py_0          28 KB
#     werkzeug-0.16.1            |             py_0         258 KB
#     wrapt-1.12.1               |   py36he774522_1          49 KB
#     yarl-1.6.2                 |   py36he774522_0         130 KB
#     ------------------------------------------------------------
#                                            Total:       180.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   _tflow_select      pkgs/main/win-64::_tflow_select-2.2.0-eigen
#   absl-py            pkgs/main/win-64::absl-py-0.11.0-py36haa95532_0
#   aiohttp            pkgs/main/win-64::aiohttp-3.6.3-py36he774522_0
#   astor              pkgs/main/win-64::astor-0.8.1-py36_0
#   async-timeout      pkgs/main/win-64::async-timeout-3.0.1-py36_0
#   blas               pkgs/main/win-64::blas-1.0-mkl
#   blinker            pkgs/main/win-64::blinker-1.4-py36_0
#   cachetools         pkgs/main/noarch::cachetools-4.1.1-py_0
#   click              pkgs/main/noarch::click-7.1.2-py_0
#   gast               pkgs/main/win-64::gast-0.2.2-py36_0
#   google-auth        pkgs/main/noarch::google-auth-1.23.0-pyhd3eb1b0_0
#   google-auth-oauth~ pkgs/main/noarch::google-auth-oauthlib-0.4.2-pyhd3eb1b0_2
#   google-pasta       pkgs/main/noarch::google-pasta-0.2.0-py_0
#   grpcio             pkgs/main/win-64::grpcio-1.31.0-py36he7da953_0
#   h5py               pkgs/main/win-64::h5py-2.10.0-py36h5e291fa_0
#   hdf5               pkgs/main/win-64::hdf5-1.10.4-h7ebc959_0
#   icc_rt             pkgs/main/win-64::icc_rt-2019.0.0-h0cc432a_1
#   idna_ssl           pkgs/main/win-64::idna_ssl-1.1.0-py36_0
#   intel-openmp       pkgs/main/win-64::intel-openmp-2020.2-254
#   keras-applications pkgs/main/noarch::keras-applications-1.0.8-py_1
#   keras-preprocessi~ pkgs/main/noarch::keras-preprocessing-1.1.0-py_1
#   libprotobuf        pkgs/main/win-64::libprotobuf-3.13.0.1-h200bbdf_0
#   markdown           pkgs/main/win-64::markdown-3.3.3-py36haa95532_0
#   mkl                pkgs/main/win-64::mkl-2020.2-256
#   mkl-service        pkgs/main/win-64::mkl-service-2.3.0-py36h2bbff1b_0
#   mkl_fft            pkgs/main/win-64::mkl_fft-1.2.0-py36h45dec08_0
#   mkl_random         pkgs/main/win-64::mkl_random-1.1.1-py36h47e9c7a_0
#   multidict          pkgs/main/win-64::multidict-4.7.6-py36he774522_1
#   numpy              pkgs/main/win-64::numpy-1.19.2-py36hadc3359_0
#   numpy-base         pkgs/main/win-64::numpy-base-1.19.2-py36ha3acd2a_0
#   oauthlib           pkgs/main/noarch::oauthlib-3.1.0-py_0
#   opt_einsum         pkgs/main/noarch::opt_einsum-3.1.0-py_0
#   protobuf           pkgs/main/win-64::protobuf-3.13.0.1-py36ha925a31_1
#   pyasn1             pkgs/main/noarch::pyasn1-0.4.8-py_0
#   pyasn1-modules     pkgs/main/noarch::pyasn1-modules-0.2.8-py_0
#   pyjwt              pkgs/main/win-64::pyjwt-1.7.1-py36_0
#   pyreadline         pkgs/main/win-64::pyreadline-2.1-py36_1
#   requests-oauthlib  pkgs/main/noarch::requests-oauthlib-1.3.0-py_0
#   rsa                pkgs/main/noarch::rsa-4.6-py_0
#   scipy              pkgs/main/win-64::scipy-1.5.2-py36h9439919_0
#   tensorboard        pkgs/main/noarch::tensorboard-2.3.0-pyh4dce500_0
#   tensorboard-plugi~ pkgs/main/noarch::tensorboard-plugin-wit-1.6.0-py_0
#   tensorflow         pkgs/main/win-64::tensorflow-2.1.0-eigen_py36hdbbabfe_0
#   tensorflow-base    pkgs/main/win-64::tensorflow-base-2.1.0-eigen_py36h49b2757_0
#   tensorflow-estima~ pkgs/main/noarch::tensorflow-estimator-2.1.0-pyhd54b08b_0
#   termcolor          pkgs/main/win-64::termcolor-1.1.0-py36_1
#   typing_extensions  pkgs/main/noarch::typing_extensions-3.7.4.3-py_0
#   werkzeug           pkgs/main/noarch::werkzeug-0.16.1-py_0
#   wrapt              pkgs/main/win-64::wrapt-1.12.1-py36he774522_1
#   yarl               pkgs/main/win-64::yarl-1.6.2-py36he774522_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2020.11.~ --> pkgs/main::ca-certificates-2020.10.14-0
#   certifi            conda-forge::certifi-2020.11.8-py36ha~ --> pkgs/main::certifi-2020.11.8-py36haa95532_0
#   openssl                                       conda-forge --> pkgs/main
#
#
#
# Downloading and Extracting Packages
#
# keras-applications-1 | 29 KB     |            |   0%
# keras-applications-1 | 29 KB     | #####5     |  56%
# keras-applications-1 | 29 KB     | ########## | 100%
# keras-applications-1 | 29 KB     | ########## | 100%
#
# tensorboard-plugin-w | 630 KB    |            |   0%
# tensorboard-plugin-w | 630 KB    | #5         |  15%
# tensorboard-plugin-w | 630 KB    | ######     |  61%
# tensorboard-plugin-w | 630 KB    | ########## | 100%
# tensorboard-plugin-w | 630 KB    | ########## | 100%
#
# google-pasta-0.2.0   | 46 KB     |            |   0%
# google-pasta-0.2.0   | 46 KB     | ########## | 100%
# google-pasta-0.2.0   | 46 KB     | ########## | 100%
#
# intel-openmp-2020.2  | 1.6 MB    |            |   0%
# intel-openmp-2020.2  | 1.6 MB    | 7          |   8%
# intel-openmp-2020.2  | 1.6 MB    | ##5        |  26%
# intel-openmp-2020.2  | 1.6 MB    | ####4      |  45%
# intel-openmp-2020.2  | 1.6 MB    | ######3    |  63%
# intel-openmp-2020.2  | 1.6 MB    | ########8  |  88%
# intel-openmp-2020.2  | 1.6 MB    | ########## | 100%
#
# multidict-4.7.6      | 60 KB     |            |   0%
# multidict-4.7.6      | 60 KB     | ########## | 100%
# multidict-4.7.6      | 60 KB     | ########## | 100%
#
# oauthlib-3.1.0       | 91 KB     |            |   0%
# oauthlib-3.1.0       | 91 KB     | ########## | 100%
# oauthlib-3.1.0       | 91 KB     | ########## | 100%
#
# termcolor-1.1.0      | 9 KB      |            |   0%
# termcolor-1.1.0      | 9 KB      | ########## | 100%
# termcolor-1.1.0      | 9 KB      | ########## | 100%
#
# protobuf-3.13.0.1    | 538 KB    |            |   0%
# protobuf-3.13.0.1    | 538 KB    | 8          |   9%
# protobuf-3.13.0.1    | 538 KB    | #######7   |  77%
# protobuf-3.13.0.1    | 538 KB    | ########## | 100%
# protobuf-3.13.0.1    | 538 KB    | ########## | 100%
#
# scipy-1.5.2          | 11.9 MB   |            |   0%
# scipy-1.5.2          | 11.9 MB   | 1          |   1%
# scipy-1.5.2          | 11.9 MB   | 4          |   4%
# scipy-1.5.2          | 11.9 MB   | 7          |   7%
# scipy-1.5.2          | 11.9 MB   | 8          |   9%
# scipy-1.5.2          | 11.9 MB   | #2         |  12%
# scipy-1.5.2          | 11.9 MB   | #5         |  15%
# scipy-1.5.2          | 11.9 MB   | #7         |  18%
# scipy-1.5.2          | 11.9 MB   | ##         |  21%
# scipy-1.5.2          | 11.9 MB   | ##4        |  24%
# scipy-1.5.2          | 11.9 MB   | ##7        |  28%
# scipy-1.5.2          | 11.9 MB   | ###        |  31%
# scipy-1.5.2          | 11.9 MB   | ###3       |  34%
# scipy-1.5.2          | 11.9 MB   | ###6       |  36%
# scipy-1.5.2          | 11.9 MB   | ###8       |  39%
# scipy-1.5.2          | 11.9 MB   | ####1      |  42%
# scipy-1.5.2          | 11.9 MB   | ####4      |  45%
# scipy-1.5.2          | 11.9 MB   | ####7      |  48%
# scipy-1.5.2          | 11.9 MB   | #####      |  51%
# scipy-1.5.2          | 11.9 MB   | #####3     |  54%
# scipy-1.5.2          | 11.9 MB   | #####6     |  56%
# scipy-1.5.2          | 11.9 MB   | #####8     |  59%
# scipy-1.5.2          | 11.9 MB   | ######1    |  62%
# scipy-1.5.2          | 11.9 MB   | ######4    |  65%
# scipy-1.5.2          | 11.9 MB   | ######8    |  68%
# scipy-1.5.2          | 11.9 MB   | #######1   |  71%
# scipy-1.5.2          | 11.9 MB   | #######4   |  74%
# scipy-1.5.2          | 11.9 MB   | #######7   |  77%
# scipy-1.5.2          | 11.9 MB   | #######9   |  80%
# scipy-1.5.2          | 11.9 MB   | ########2  |  82%
# scipy-1.5.2          | 11.9 MB   | ########5  |  86%
# scipy-1.5.2          | 11.9 MB   | ########8  |  88%
# scipy-1.5.2          | 11.9 MB   | #########  |  91%
# scipy-1.5.2          | 11.9 MB   | #########3 |  94%
# scipy-1.5.2          | 11.9 MB   | #########6 |  97%
# scipy-1.5.2          | 11.9 MB   | #########9 | 100%
# scipy-1.5.2          | 11.9 MB   | ########## | 100%
#
# cachetools-4.1.1     | 12 KB     |            |   0%
# cachetools-4.1.1     | 12 KB     | ########## | 100%
# cachetools-4.1.1     | 12 KB     | ########## | 100%
#
# grpcio-1.31.0        | 1.5 MB    |            |   0%
# grpcio-1.31.0        | 1.5 MB    | 1          |   1%
# grpcio-1.31.0        | 1.5 MB    | ##6        |  27%
# grpcio-1.31.0        | 1.5 MB    | #####1     |  51%
# grpcio-1.31.0        | 1.5 MB    | ######9    |  69%
# grpcio-1.31.0        | 1.5 MB    | #########3 |  94%
# grpcio-1.31.0        | 1.5 MB    | ########## | 100%
#
# aiohttp-3.6.3        | 512 KB    |            |   0%
# aiohttp-3.6.3        | 512 KB    | #2         |  12%
# aiohttp-3.6.3        | 512 KB    | #########6 |  97%
# aiohttp-3.6.3        | 512 KB    | ########## | 100%
#
# typing_extensions-3. | 28 KB     |            |   0%
# typing_extensions-3. | 28 KB     | ########## | 100%
# typing_extensions-3. | 28 KB     | ########## | 100%
#
# pyreadline-2.1       | 143 KB    |            |   0%
# pyreadline-2.1       | 143 KB    | ###3       |  34%
# pyreadline-2.1       | 143 KB    | ########## | 100%
# pyreadline-2.1       | 143 KB    | ########## | 100%
#
# numpy-1.19.2         | 22 KB     |            |   0%
# numpy-1.19.2         | 22 KB     | ########## | 100%
# numpy-1.19.2         | 22 KB     | ########## | 100%
#
# openssl-1.1.1h       | 4.8 MB    |            |   0%
# openssl-1.1.1h       | 4.8 MB    | 2          |   3%
# openssl-1.1.1h       | 4.8 MB    | 9          |  10%
# openssl-1.1.1h       | 4.8 MB    | #7         |  17%
# openssl-1.1.1h       | 4.8 MB    | ##4        |  25%
# openssl-1.1.1h       | 4.8 MB    | ###        |  30%
# openssl-1.1.1h       | 4.8 MB    | ###7       |  37%
# openssl-1.1.1h       | 4.8 MB    | ####2      |  43%
# openssl-1.1.1h       | 4.8 MB    | #####1     |  52%
# openssl-1.1.1h       | 4.8 MB    | #####7     |  58%
# openssl-1.1.1h       | 4.8 MB    | ######3    |  64%
# openssl-1.1.1h       | 4.8 MB    | #######    |  71%
# openssl-1.1.1h       | 4.8 MB    | #######8   |  79%
# openssl-1.1.1h       | 4.8 MB    | ########7  |  88%
# openssl-1.1.1h       | 4.8 MB    | #########4 |  95%
# openssl-1.1.1h       | 4.8 MB    | ########## | 100%
#
# keras-preprocessing- | 37 KB     |            |   0%
# keras-preprocessing- | 37 KB     | ########## | 100%
# keras-preprocessing- | 37 KB     | ########## | 100%
#
# mkl-service-2.3.0    | 45 KB     |            |   0%
# mkl-service-2.3.0    | 45 KB     | ########## | 100%
# mkl-service-2.3.0    | 45 KB     | ########## | 100%
#
# mkl_fft-1.2.0        | 118 KB    |            |   0%
# mkl_fft-1.2.0        | 118 KB    | #3         |  14%
# mkl_fft-1.2.0        | 118 KB    | ########## | 100%
# mkl_fft-1.2.0        | 118 KB    | ########## | 100%
#
# tensorboard-2.3.0    | 5.2 MB    |            |   0%
# tensorboard-2.3.0    | 5.2 MB    |            |   0%
# tensorboard-2.3.0    | 5.2 MB    | 5          |   6%
# tensorboard-2.3.0    | 5.2 MB    | #2         |  12%
# tensorboard-2.3.0    | 5.2 MB    | #7         |  17%
# tensorboard-2.3.0    | 5.2 MB    | ##2        |  22%
# tensorboard-2.3.0    | 5.2 MB    | ##6        |  26%
# tensorboard-2.3.0    | 5.2 MB    | ###        |  30%
# tensorboard-2.3.0    | 5.2 MB    | ###4       |  35%
# tensorboard-2.3.0    | 5.2 MB    | ####       |  40%
# tensorboard-2.3.0    | 5.2 MB    | ####5      |  45%
# tensorboard-2.3.0    | 5.2 MB    | ####9      |  50%
# tensorboard-2.3.0    | 5.2 MB    | #####6     |  56%
# tensorboard-2.3.0    | 5.2 MB    | ######2    |  63%
# tensorboard-2.3.0    | 5.2 MB    | ######7    |  68%
# tensorboard-2.3.0    | 5.2 MB    | #######6   |  77%
# tensorboard-2.3.0    | 5.2 MB    | ########2  |  82%
# tensorboard-2.3.0    | 5.2 MB    | ########8  |  88%
# tensorboard-2.3.0    | 5.2 MB    | #########3 |  94%
# tensorboard-2.3.0    | 5.2 MB    | ########## | 100%
# tensorboard-2.3.0    | 5.2 MB    | ########## | 100%
#
# google-auth-oauthlib | 18 KB     |            |   0%
# google-auth-oauthlib | 18 KB     | ########## | 100%
# google-auth-oauthlib | 18 KB     | ########## | 100%
#
# markdown-3.3.3       | 143 KB    |            |   0%
# markdown-3.3.3       | 143 KB    | #######8   |  79%
# markdown-3.3.3       | 143 KB    | ########## | 100%
#
# tensorflow-base-2.1. | 35.4 MB   |            |   0%
# tensorflow-base-2.1. | 35.4 MB   |            |   0%
# tensorflow-base-2.1. | 35.4 MB   |            |   1%
# tensorflow-base-2.1. | 35.4 MB   | 1          |   2%
# tensorflow-base-2.1. | 35.4 MB   | 2          |   3%
# tensorflow-base-2.1. | 35.4 MB   | 3          |   3%
# tensorflow-base-2.1. | 35.4 MB   | 4          |   4%
# tensorflow-base-2.1. | 35.4 MB   | 5          |   5%
# tensorflow-base-2.1. | 35.4 MB   | 6          |   6%
# tensorflow-base-2.1. | 35.4 MB   | 6          |   7%
# tensorflow-base-2.1. | 35.4 MB   | 7          |   8%
# tensorflow-base-2.1. | 35.4 MB   | 8          |   8%
# tensorflow-base-2.1. | 35.4 MB   | 9          |   9%
# tensorflow-base-2.1. | 35.4 MB   | #          |  10%
# tensorflow-base-2.1. | 35.4 MB   | #1         |  11%
# tensorflow-base-2.1. | 35.4 MB   | #2         |  13%
# tensorflow-base-2.1. | 35.4 MB   | #3         |  14%
# tensorflow-base-2.1. | 35.4 MB   | #4         |  15%
# tensorflow-base-2.1. | 35.4 MB   | #5         |  16%
# tensorflow-base-2.1. | 35.4 MB   | #6         |  16%
# tensorflow-base-2.1. | 35.4 MB   | #7         |  17%
# tensorflow-base-2.1. | 35.4 MB   | #7         |  18%
# tensorflow-base-2.1. | 35.4 MB   | #8         |  18%
# tensorflow-base-2.1. | 35.4 MB   | #9         |  19%
# tensorflow-base-2.1. | 35.4 MB   | #9         |  20%
# tensorflow-base-2.1. | 35.4 MB   | ##         |  20%
# tensorflow-base-2.1. | 35.4 MB   | ##         |  21%
# tensorflow-base-2.1. | 35.4 MB   | ##1        |  22%
# tensorflow-base-2.1. | 35.4 MB   | ##2        |  23%
# tensorflow-base-2.1. | 35.4 MB   | ##3        |  24%
# tensorflow-base-2.1. | 35.4 MB   | ##4        |  25%
# tensorflow-base-2.1. | 35.4 MB   | ##5        |  25%
# tensorflow-base-2.1. | 35.4 MB   | ##6        |  26%
# tensorflow-base-2.1. | 35.4 MB   | ##7        |  27%
# tensorflow-base-2.1. | 35.4 MB   | ##7        |  28%
# tensorflow-base-2.1. | 35.4 MB   | ##8        |  29%
# tensorflow-base-2.1. | 35.4 MB   | ##9        |  30%
# tensorflow-base-2.1. | 35.4 MB   | ###        |  30%
# tensorflow-base-2.1. | 35.4 MB   | ###1       |  31%
# tensorflow-base-2.1. | 35.4 MB   | ###2       |  32%
# tensorflow-base-2.1. | 35.4 MB   | ###2       |  33%
# tensorflow-base-2.1. | 35.4 MB   | ###3       |  34%
# tensorflow-base-2.1. | 35.4 MB   | ###4       |  35%
# tensorflow-base-2.1. | 35.4 MB   | ###5       |  36%
# tensorflow-base-2.1. | 35.4 MB   | ###6       |  37%
# tensorflow-base-2.1. | 35.4 MB   | ###7       |  37%
# tensorflow-base-2.1. | 35.4 MB   | ###7       |  38%
# tensorflow-base-2.1. | 35.4 MB   | ###8       |  39%
# tensorflow-base-2.1. | 35.4 MB   | ###9       |  39%
# tensorflow-base-2.1. | 35.4 MB   | ####       |  40%
# tensorflow-base-2.1. | 35.4 MB   | ####1      |  41%
# tensorflow-base-2.1. | 35.4 MB   | ####1      |  42%
# tensorflow-base-2.1. | 35.4 MB   | ####2      |  43%
# tensorflow-base-2.1. | 35.4 MB   | ####3      |  43%
# tensorflow-base-2.1. | 35.4 MB   | ####4      |  44%
# tensorflow-base-2.1. | 35.4 MB   | ####5      |  45%
# tensorflow-base-2.1. | 35.4 MB   | ####5      |  46%
# tensorflow-base-2.1. | 35.4 MB   | ####6      |  47%
# tensorflow-base-2.1. | 35.4 MB   | ####7      |  47%
# tensorflow-base-2.1. | 35.4 MB   | ####8      |  48%
# tensorflow-base-2.1. | 35.4 MB   | ####8      |  49%
# tensorflow-base-2.1. | 35.4 MB   | ####9      |  50%
# tensorflow-base-2.1. | 35.4 MB   | #####      |  50%
# tensorflow-base-2.1. | 35.4 MB   | #####1     |  51%
# tensorflow-base-2.1. | 35.4 MB   | #####2     |  52%
# tensorflow-base-2.1. | 35.4 MB   | #####2     |  53%
# tensorflow-base-2.1. | 35.4 MB   | #####3     |  54%
# tensorflow-base-2.1. | 35.4 MB   | #####4     |  55%
# tensorflow-base-2.1. | 35.4 MB   | #####5     |  56%
# tensorflow-base-2.1. | 35.4 MB   | #####6     |  56%
# tensorflow-base-2.1. | 35.4 MB   | #####7     |  57%
# tensorflow-base-2.1. | 35.4 MB   | #####8     |  58%
# tensorflow-base-2.1. | 35.4 MB   | #####9     |  59%
# tensorflow-base-2.1. | 35.4 MB   | ######     |  60%
# tensorflow-base-2.1. | 35.4 MB   | ######     |  61%
# tensorflow-base-2.1. | 35.4 MB   | ######1    |  62%
# tensorflow-base-2.1. | 35.4 MB   | ######2    |  62%
# tensorflow-base-2.1. | 35.4 MB   | ######3    |  63%
# tensorflow-base-2.1. | 35.4 MB   | ######3    |  64%
# tensorflow-base-2.1. | 35.4 MB   | ######4    |  65%
# tensorflow-base-2.1. | 35.4 MB   | ######5    |  66%
# tensorflow-base-2.1. | 35.4 MB   | ######7    |  67%
# tensorflow-base-2.1. | 35.4 MB   | ######8    |  69%
# tensorflow-base-2.1. | 35.4 MB   | ######9    |  70%
# tensorflow-base-2.1. | 35.4 MB   | #######1   |  71%
# tensorflow-base-2.1. | 35.4 MB   | #######2   |  72%
# tensorflow-base-2.1. | 35.4 MB   | #######3   |  74%
# tensorflow-base-2.1. | 35.4 MB   | #######4   |  75%
# tensorflow-base-2.1. | 35.4 MB   | #######6   |  76%
# tensorflow-base-2.1. | 35.4 MB   | #######7   |  77%
# tensorflow-base-2.1. | 35.4 MB   | #######8   |  78%
# tensorflow-base-2.1. | 35.4 MB   | #######9   |  79%
# tensorflow-base-2.1. | 35.4 MB   | ########   |  81%
# tensorflow-base-2.1. | 35.4 MB   | ########1  |  82%
# tensorflow-base-2.1. | 35.4 MB   | ########2  |  83%
# tensorflow-base-2.1. | 35.4 MB   | ########3  |  84%
# tensorflow-base-2.1. | 35.4 MB   | ########5  |  85%
# tensorflow-base-2.1. | 35.4 MB   | ########6  |  86%
# tensorflow-base-2.1. | 35.4 MB   | ########7  |  87%
# tensorflow-base-2.1. | 35.4 MB   | ########8  |  88%
# tensorflow-base-2.1. | 35.4 MB   | ########9  |  89%
# tensorflow-base-2.1. | 35.4 MB   | #########  |  90%
# tensorflow-base-2.1. | 35.4 MB   | #########1 |  91%
# tensorflow-base-2.1. | 35.4 MB   | #########2 |  92%
# tensorflow-base-2.1. | 35.4 MB   | #########3 |  93%
# tensorflow-base-2.1. | 35.4 MB   | #########4 |  94%
# tensorflow-base-2.1. | 35.4 MB   | #########5 |  95%
# tensorflow-base-2.1. | 35.4 MB   | #########6 |  96%
# tensorflow-base-2.1. | 35.4 MB   | #########7 |  97%
# tensorflow-base-2.1. | 35.4 MB   | #########7 |  98%
# tensorflow-base-2.1. | 35.4 MB   | #########8 |  98%
# tensorflow-base-2.1. | 35.4 MB   | #########9 |  99%
# tensorflow-base-2.1. | 35.4 MB   | #########9 | 100%
# tensorflow-base-2.1. | 35.4 MB   | ########## | 100%
#
# gast-0.2.2           | 155 KB    |            |   0%
# gast-0.2.2           | 155 KB    | #########2 |  93%
# gast-0.2.2           | 155 KB    | ########## | 100%
#
# pyasn1-0.4.8         | 57 KB     |            |   0%
# pyasn1-0.4.8         | 57 KB     | ########## | 100%
# pyasn1-0.4.8         | 57 KB     | ########## | 100%
#
# blinker-1.4          | 22 KB     |            |   0%
# blinker-1.4          | 22 KB     | ########## | 100%
# blinker-1.4          | 22 KB     | ########## | 100%
#
# google-auth-1.23.0   | 61 KB     |            |   0%
# google-auth-1.23.0   | 61 KB     | ########## | 100%
# google-auth-1.23.0   | 61 KB     | ########## | 100%
#
# _tflow_select-2.2.0  | 3 KB      |            |   0%
# _tflow_select-2.2.0  | 3 KB      | ########## | 100%
# _tflow_select-2.2.0  | 3 KB      | ########## | 100%
#
# async-timeout-3.0.1  | 12 KB     |            |   0%
# async-timeout-3.0.1  | 12 KB     | ########## | 100%
# async-timeout-3.0.1  | 12 KB     | ########## | 100%
#
# pyjwt-1.7.1          | 49 KB     |            |   0%
# pyjwt-1.7.1          | 49 KB     | ########## | 100%
# pyjwt-1.7.1          | 49 KB     | ########## | 100%
#
# mkl-2020.2           | 109.3 MB  |            |   0%
# mkl-2020.2           | 109.3 MB  |            |   0%
# mkl-2020.2           | 109.3 MB  |            |   0%
# mkl-2020.2           | 109.3 MB  |            |   1%
# mkl-2020.2           | 109.3 MB  |            |   1%
# mkl-2020.2           | 109.3 MB  |            |   1%
# mkl-2020.2           | 109.3 MB  | 1          |   1%
# mkl-2020.2           | 109.3 MB  | 1          |   1%
# mkl-2020.2           | 109.3 MB  | 1          |   2%
# mkl-2020.2           | 109.3 MB  | 1          |   2%
# mkl-2020.2           | 109.3 MB  | 2          |   2%
# mkl-2020.2           | 109.3 MB  | 2          |   2%
# mkl-2020.2           | 109.3 MB  | 2          |   3%
# mkl-2020.2           | 109.3 MB  | 2          |   3%
# mkl-2020.2           | 109.3 MB  | 3          |   3%
# mkl-2020.2           | 109.3 MB  | 3          |   3%
# mkl-2020.2           | 109.3 MB  | 3          |   4%
# mkl-2020.2           | 109.3 MB  | 3          |   4%
# mkl-2020.2           | 109.3 MB  | 4          |   4%
# mkl-2020.2           | 109.3 MB  | 4          |   4%
# mkl-2020.2           | 109.3 MB  | 4          |   5%
# mkl-2020.2           | 109.3 MB  | 5          |   5%
# mkl-2020.2           | 109.3 MB  | 5          |   5%
# mkl-2020.2           | 109.3 MB  | 5          |   6%
# mkl-2020.2           | 109.3 MB  | 5          |   6%
# mkl-2020.2           | 109.3 MB  | 6          |   6%
# mkl-2020.2           | 109.3 MB  | 6          |   7%
# mkl-2020.2           | 109.3 MB  | 6          |   7%
# mkl-2020.2           | 109.3 MB  | 7          |   7%
# mkl-2020.2           | 109.3 MB  | 7          |   7%
# mkl-2020.2           | 109.3 MB  | 7          |   8%
# mkl-2020.2           | 109.3 MB  | 7          |   8%
# mkl-2020.2           | 109.3 MB  | 8          |   8%
# mkl-2020.2           | 109.3 MB  | 8          |   9%
# mkl-2020.2           | 109.3 MB  | 8          |   9%
# mkl-2020.2           | 109.3 MB  | 9          |   9%
# mkl-2020.2           | 109.3 MB  | 9          |  10%
# mkl-2020.2           | 109.3 MB  | 9          |  10%
# mkl-2020.2           | 109.3 MB  | #          |  10%
# mkl-2020.2           | 109.3 MB  | #          |  11%
# mkl-2020.2           | 109.3 MB  | #          |  11%
# mkl-2020.2           | 109.3 MB  | #1         |  11%
# mkl-2020.2           | 109.3 MB  | #1         |  12%
# mkl-2020.2           | 109.3 MB  | #1         |  12%
# mkl-2020.2           | 109.3 MB  | #2         |  12%
# mkl-2020.2           | 109.3 MB  | #2         |  12%
# mkl-2020.2           | 109.3 MB  | #2         |  12%
# mkl-2020.2           | 109.3 MB  | #2         |  13%
# mkl-2020.2           | 109.3 MB  | #3         |  13%
# mkl-2020.2           | 109.3 MB  | #3         |  13%
# mkl-2020.2           | 109.3 MB  | #3         |  14%
# mkl-2020.2           | 109.3 MB  | #4         |  14%
# mkl-2020.2           | 109.3 MB  | #4         |  14%
# mkl-2020.2           | 109.3 MB  | #4         |  15%
# mkl-2020.2           | 109.3 MB  | #5         |  15%
# mkl-2020.2           | 109.3 MB  | #5         |  16%
# mkl-2020.2           | 109.3 MB  | #5         |  16%
# mkl-2020.2           | 109.3 MB  | #6         |  16%
# mkl-2020.2           | 109.3 MB  | #6         |  17%
# mkl-2020.2           | 109.3 MB  | #7         |  17%
# mkl-2020.2           | 109.3 MB  | #7         |  17%
# mkl-2020.2           | 109.3 MB  | #7         |  18%
# mkl-2020.2           | 109.3 MB  | #8         |  18%
# mkl-2020.2           | 109.3 MB  | #8         |  19%
# mkl-2020.2           | 109.3 MB  | #9         |  19%
# mkl-2020.2           | 109.3 MB  | #9         |  20%
# mkl-2020.2           | 109.3 MB  | ##         |  20%
# mkl-2020.2           | 109.3 MB  | ##         |  21%
# mkl-2020.2           | 109.3 MB  | ##         |  21%
# mkl-2020.2           | 109.3 MB  | ##1        |  21%
# mkl-2020.2           | 109.3 MB  | ##1        |  22%
# mkl-2020.2           | 109.3 MB  | ##2        |  22%
# mkl-2020.2           | 109.3 MB  | ##2        |  23%
# mkl-2020.2           | 109.3 MB  | ##3        |  23%
# mkl-2020.2           | 109.3 MB  | ##3        |  23%
# mkl-2020.2           | 109.3 MB  | ##3        |  24%
# mkl-2020.2           | 109.3 MB  | ##4        |  24%
# mkl-2020.2           | 109.3 MB  | ##4        |  25%
# mkl-2020.2           | 109.3 MB  | ##4        |  25%
# mkl-2020.2           | 109.3 MB  | ##5        |  25%
# mkl-2020.2           | 109.3 MB  | ##5        |  26%
# mkl-2020.2           | 109.3 MB  | ##6        |  26%
# mkl-2020.2           | 109.3 MB  | ##6        |  26%
# mkl-2020.2           | 109.3 MB  | ##6        |  27%
# mkl-2020.2           | 109.3 MB  | ##7        |  27%
# mkl-2020.2           | 109.3 MB  | ##7        |  27%
# mkl-2020.2           | 109.3 MB  | ##7        |  28%
# mkl-2020.2           | 109.3 MB  | ##8        |  28%
# mkl-2020.2           | 109.3 MB  | ##8        |  29%
# mkl-2020.2           | 109.3 MB  | ##9        |  29%
# mkl-2020.2           | 109.3 MB  | ##9        |  30%
# mkl-2020.2           | 109.3 MB  | ###        |  30%
# mkl-2020.2           | 109.3 MB  | ###        |  31%
# mkl-2020.2           | 109.3 MB  | ###        |  31%
# mkl-2020.2           | 109.3 MB  | ###1       |  31%
# mkl-2020.2           | 109.3 MB  | ###1       |  32%
# mkl-2020.2           | 109.3 MB  | ###1       |  32%
# mkl-2020.2           | 109.3 MB  | ###2       |  32%
# mkl-2020.2           | 109.3 MB  | ###2       |  33%
# mkl-2020.2           | 109.3 MB  | ###2       |  33%
# mkl-2020.2           | 109.3 MB  | ###3       |  33%
# mkl-2020.2           | 109.3 MB  | ###3       |  33%
# mkl-2020.2           | 109.3 MB  | ###3       |  34%
# mkl-2020.2           | 109.3 MB  | ###4       |  34%
# mkl-2020.2           | 109.3 MB  | ###4       |  34%
# mkl-2020.2           | 109.3 MB  | ###4       |  35%
# mkl-2020.2           | 109.3 MB  | ###5       |  35%
# mkl-2020.2           | 109.3 MB  | ###5       |  35%
# mkl-2020.2           | 109.3 MB  | ###5       |  36%
# mkl-2020.2           | 109.3 MB  | ###5       |  36%
# mkl-2020.2           | 109.3 MB  | ###6       |  36%
# mkl-2020.2           | 109.3 MB  | ###6       |  37%
# mkl-2020.2           | 109.3 MB  | ###6       |  37%
# mkl-2020.2           | 109.3 MB  | ###7       |  37%
# mkl-2020.2           | 109.3 MB  | ###7       |  38%
# mkl-2020.2           | 109.3 MB  | ###7       |  38%
# mkl-2020.2           | 109.3 MB  | ###8       |  38%
# mkl-2020.2           | 109.3 MB  | ###8       |  39%
# mkl-2020.2           | 109.3 MB  | ###8       |  39%
# mkl-2020.2           | 109.3 MB  | ###9       |  39%
# mkl-2020.2           | 109.3 MB  | ###9       |  40%
# mkl-2020.2           | 109.3 MB  | ###9       |  40%
# mkl-2020.2           | 109.3 MB  | ####       |  40%
# mkl-2020.2           | 109.3 MB  | ####       |  40%
# mkl-2020.2           | 109.3 MB  | ####       |  41%
# mkl-2020.2           | 109.3 MB  | ####1      |  41%
# mkl-2020.2           | 109.3 MB  | ####1      |  41%
# mkl-2020.2           | 109.3 MB  | ########9  |  89%
# mkl-2020.2           | 109.3 MB  | ########9  |  89%
# mkl-2020.2           | 109.3 MB  | ########9  |  90%
# mkl-2020.2           | 109.3 MB  | #########  |  90%
# mkl-2020.2           | 109.3 MB  | #########  |  90%
# mkl-2020.2           | 109.3 MB  | #########  |  91%
# mkl-2020.2           | 109.3 MB  | #########  |  91%
# mkl-2020.2           | 109.3 MB  | #########1 |  91%
# mkl-2020.2           | 109.3 MB  | #########1 |  92%
# mkl-2020.2           | 109.3 MB  | #########1 |  92%
# mkl-2020.2           | 109.3 MB  | #########2 |  92%
# mkl-2020.2           | 109.3 MB  | #########2 |  92%
# mkl-2020.2           | 109.3 MB  | #########2 |  93%
# mkl-2020.2           | 109.3 MB  | #########3 |  93%
# mkl-2020.2           | 109.3 MB  | #########3 |  93%
# mkl-2020.2           | 109.3 MB  | #########3 |  94%
# mkl-2020.2           | 109.3 MB  | #########4 |  94%
# mkl-2020.2           | 109.3 MB  | #########4 |  94%
# mkl-2020.2           | 109.3 MB  | #########4 |  95%
# mkl-2020.2           | 109.3 MB  | #########4 |  95%
# mkl-2020.2           | 109.3 MB  | #########5 |  95%
# mkl-2020.2           | 109.3 MB  | #########5 |  95%
# mkl-2020.2           | 109.3 MB  | #########5 |  96%
# mkl-2020.2           | 109.3 MB  | #########5 |  96%
# mkl-2020.2           | 109.3 MB  | #########6 |  96%
# mkl-2020.2           | 109.3 MB  | #########6 |  96%
# mkl-2020.2           | 109.3 MB  | #########6 |  97%
# mkl-2020.2           | 109.3 MB  | #########7 |  97%
# mkl-2020.2           | 109.3 MB  | #########7 |  97%
# mkl-2020.2           | 109.3 MB  | #########7 |  98%
# mkl-2020.2           | 109.3 MB  | #########7 |  98%
# mkl-2020.2           | 109.3 MB  | #########8 |  98%
# mkl-2020.2           | 109.3 MB  | #########8 |  98%
# mkl-2020.2           | 109.3 MB  | #########8 |  99%
# mkl-2020.2           | 109.3 MB  | #########8 |  99%
# mkl-2020.2           | 109.3 MB  | #########9 |  99%
# mkl-2020.2           | 109.3 MB  | #########9 | 100%
# mkl-2020.2           | 109.3 MB  | ########## | 100%
# mkl-2020.2           | 109.3 MB  | ########## | 100%
#
# ca-certificates-2020 | 122 KB    |            |   0%
# ca-certificates-2020 | 122 KB    | ######5    |  66%
# ca-certificates-2020 | 122 KB    | ########## | 100%
# ca-certificates-2020 | 122 KB    | ########## | 100%
#
# wrapt-1.12.1         | 49 KB     |            |   0%
# wrapt-1.12.1         | 49 KB     | ########## | 100%
# wrapt-1.12.1         | 49 KB     | ########## | 100%
#
# mkl_random-1.1.1     | 235 KB    |            |   0%
# mkl_random-1.1.1     | 235 KB    | ####       |  41%
# mkl_random-1.1.1     | 235 KB    | ########## | 100%
# mkl_random-1.1.1     | 235 KB    | ########## | 100%
#
# werkzeug-0.16.1      | 258 KB    |            |   0%
# werkzeug-0.16.1      | 258 KB    | ##4        |  25%
# werkzeug-0.16.1      | 258 KB    | ######8    |  68%
# werkzeug-0.16.1      | 258 KB    | ########## | 100%
# werkzeug-0.16.1      | 258 KB    | ########## | 100%
#
# numpy-base-1.19.2    | 3.8 MB    |            |   0%
# numpy-base-1.19.2    | 3.8 MB    | 3          |   3%
# numpy-base-1.19.2    | 3.8 MB    | 7          |   7%
# numpy-base-1.19.2    | 3.8 MB    | #4         |  15%
# numpy-base-1.19.2    | 3.8 MB    | #8         |  19%
# numpy-base-1.19.2    | 3.8 MB    | ##2        |  23%
# numpy-base-1.19.2    | 3.8 MB    | ##9        |  29%
# numpy-base-1.19.2    | 3.8 MB    | ###6       |  36%
# numpy-base-1.19.2    | 3.8 MB    | ####5      |  45%
# numpy-base-1.19.2    | 3.8 MB    | #####1     |  52%
# numpy-base-1.19.2    | 3.8 MB    | #####7     |  58%
# numpy-base-1.19.2    | 3.8 MB    | ######5    |  66%
# numpy-base-1.19.2    | 3.8 MB    | #######1   |  72%
# numpy-base-1.19.2    | 3.8 MB    | ########1  |  82%
# numpy-base-1.19.2    | 3.8 MB    | ########8  |  88%
# numpy-base-1.19.2    | 3.8 MB    | #########5 |  96%
# numpy-base-1.19.2    | 3.8 MB    | ########## | 100%
#
# yarl-1.6.2           | 130 KB    |            |   0%
# yarl-1.6.2           | 130 KB    | #2         |  12%
# yarl-1.6.2           | 130 KB    | ########## | 100%
# yarl-1.6.2           | 130 KB    | ########## | 100%
#
# rsa-4.6              | 26 KB     |            |   0%
# rsa-4.6              | 26 KB     | ########## | 100%
# rsa-4.6              | 26 KB     | ########## | 100%
#
# libprotobuf-3.13.0.1 | 1.8 MB    |            |   0%
# libprotobuf-3.13.0.1 | 1.8 MB    | 8          |   8%
# libprotobuf-3.13.0.1 | 1.8 MB    | #2         |  13%
# libprotobuf-3.13.0.1 | 1.8 MB    | ##7        |  28%
# libprotobuf-3.13.0.1 | 1.8 MB    | ####3      |  43%
# libprotobuf-3.13.0.1 | 1.8 MB    | #####      |  51%
# libprotobuf-3.13.0.1 | 1.8 MB    | ######1    |  62%
# libprotobuf-3.13.0.1 | 1.8 MB    | #######6   |  76%
# libprotobuf-3.13.0.1 | 1.8 MB    | #########1 |  91%
# libprotobuf-3.13.0.1 | 1.8 MB    | ########## | 100%
#
# tensorflow-2.1.0     | 4 KB      |            |   0%
# tensorflow-2.1.0     | 4 KB      | ########## | 100%
# tensorflow-2.1.0     | 4 KB      | ########## | 100%
#
# requests-oauthlib-1. | 23 KB     |            |   0%
# requests-oauthlib-1. | 23 KB     | ########## | 100%
# requests-oauthlib-1. | 23 KB     | ########## | 100%
#
# idna_ssl-1.1.0       | 7 KB      |            |   0%
# idna_ssl-1.1.0       | 7 KB      | ########## | 100%
# idna_ssl-1.1.0       | 7 KB      | ########## | 100%
#
# tensorflow-estimator | 251 KB    |            |   0%
# tensorflow-estimator | 251 KB    | #######    |  70%
# tensorflow-estimator | 251 KB    | ########## | 100%
# tensorflow-estimator | 251 KB    | ########## | 100%
#
# astor-0.8.1          | 47 KB     |            |   0%
# astor-0.8.1          | 47 KB     | ########## | 100%
# astor-0.8.1          | 47 KB     | ########## | 100%
#
# h5py-2.10.0          | 807 KB    |            |   0%
# h5py-2.10.0          | 807 KB    | #3         |  14%
# h5py-2.10.0          | 807 KB    | ####7      |  48%
# h5py-2.10.0          | 807 KB    | ######5    |  65%
# h5py-2.10.0          | 807 KB    | #########5 |  95%
# h5py-2.10.0          | 807 KB    | ########## | 100%
#
# absl-py-0.11.0       | 192 KB    |            |   0%
# absl-py-0.11.0       | 192 KB    | #####      |  50%
# absl-py-0.11.0       | 192 KB    | ########## | 100%
# absl-py-0.11.0       | 192 KB    | ########## | 100%
#
# opt_einsum-3.1.0     | 54 KB     |            |   0%
# opt_einsum-3.1.0     | 54 KB     | ########## | 100%
# opt_einsum-3.1.0     | 54 KB     | ########## | 100%
#
# click-7.1.2          | 71 KB     |            |   0%
# click-7.1.2          | 71 KB     | ########## | 100%
# click-7.1.2          | 71 KB     | ########## | 100%
#
# pyasn1-modules-0.2.8 | 72 KB     |            |   0%
# pyasn1-modules-0.2.8 | 72 KB     | ########## | 100%
# pyasn1-modules-0.2.8 | 72 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# tensorflow installed
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\xinyu\anaconda3\envs\Seminar_csma
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.10.14 |                0         159 KB  anaconda
#     certifi-2020.6.20          |           py36_0         160 KB  anaconda
#     openssl-1.1.1h             |       he774522_0         5.8 MB  anaconda
#     pandas-1.1.3               |   py36ha925a31_0         9.4 MB  anaconda
#     pytz-2020.1                |             py_0         239 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:        15.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas             anaconda/win-64::pandas-1.1.3-py36ha925a31_0
#   pytz               anaconda/noarch::pytz-2020.1-py_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates                                 pkgs/main --> anaconda
#   certifi            pkgs/main::certifi-2020.11.8-py36haa9~ --> anaconda::certifi-2020.6.20-py36_0
#   openssl                                         pkgs/main --> anaconda
#
#
#
# Downloading and Extracting Packages
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | 6          |   7%
# pytz-2020.1          | 239 KB    | #####3     |  54%
# pytz-2020.1          | 239 KB    | ########## | 100%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# pandas-1.1.3         | 9.4 MB    |            |   0%
# pandas-1.1.3         | 9.4 MB    |            |   0%
# pandas-1.1.3         | 9.4 MB    | 1          |   2%
# pandas-1.1.3         | 9.4 MB    | 5          |   6%
# pandas-1.1.3         | 9.4 MB    | 7          |   7%
# pandas-1.1.3         | 9.4 MB    | #1         |  11%
# pandas-1.1.3         | 9.4 MB    | #3         |  14%
# pandas-1.1.3         | 9.4 MB    | #6         |  17%
# pandas-1.1.3         | 9.4 MB    | #9         |  20%
# pandas-1.1.3         | 9.4 MB    | ##4        |  24%
# pandas-1.1.3         | 9.4 MB    | ##7        |  28%
# pandas-1.1.3         | 9.4 MB    | ###1       |  32%
# pandas-1.1.3         | 9.4 MB    | ###4       |  35%
# pandas-1.1.3         | 9.4 MB    | ###8       |  38%
# pandas-1.1.3         | 9.4 MB    | ####1      |  41%
# pandas-1.1.3         | 9.4 MB    | ####3      |  44%
# ...
# qt-5.12.9            | 106.3 MB  | ##7        |  27%
# qt-5.12.9            | 106.3 MB  | ##7        |  28%
# qt-5.12.9            | 106.3 MB  | ##8        |  28%
# qt-5.12.9            | 106.3 MB  | ##8        |  28%
# qt-5.12.9            | 106.3 MB  | ##8        |  29%
# qt-5.12.9            | 106.3 MB  | ##9        |  29%
# qt-5.12.9            | 106.3 MB  | #########9 | 100%
# qt-5.12.9            | 106.3 MB  | ########## | 100%
#
# zstd-1.4.5           | 887 KB    |            |   0%
# zstd-1.4.5           | 887 KB    | 9          |   9%
# zstd-1.4.5           | 887 KB    | #####2     |  52%
# zstd-1.4.5           | 887 KB    | #########2 |  92%
# zstd-1.4.5           | 887 KB    | ########## | 100%
#
# freetype-2.10.4      | 493 KB    |            |   0%
# freetype-2.10.4      | 493 KB    | ##9        |  29%
# freetype-2.10.4      | 493 KB    | ########## | 100%
# freetype-2.10.4      | 493 KB    | ########## | 100%
#
# jpeg-9d              | 366 KB    |            |   0%
# jpeg-9d              | 366 KB    | 4          |   4%
# jpeg-9d              | 366 KB    | #########6 |  96%
# jpeg-9d              | 366 KB    | ########## | 100%
#
# kiwisolver-1.3.1     | 58 KB     |            |   0%
# kiwisolver-1.3.1     | 58 KB     | ########## | 100%
# kiwisolver-1.3.1     | 58 KB     | ########## | 100%
#
# xz-5.2.5             | 211 KB    |            |   0%
# xz-5.2.5             | 211 KB    | ######     |  61%
# xz-5.2.5             | 211 KB    | ########## | 100%
# xz-5.2.5             | 211 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# matplotlib installed
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\xinyu\anaconda3\envs\Seminar_csma
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1h             |       he774522_0         5.8 MB  anaconda
#     seaborn-0.11.0             |             py_0         216 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         6.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   seaborn            anaconda/noarch::seaborn-0.11.0-py_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2020.11.~ --> anaconda::ca-certificates-2020.10.14-0
#   certifi            conda-forge::certifi-2020.11.8-py36ha~ --> anaconda::certifi-2020.6.20-py36_0
#   openssl                                       conda-forge --> anaconda
#
#
#
# Downloading and Extracting Packages
#
# seaborn-0.11.0       | 216 KB    |            |   0%
# seaborn-0.11.0       | 216 KB    | 7          |   7%
# seaborn-0.11.0       | 216 KB    | ########## | 100%
# seaborn-0.11.0       | 216 KB    | ########## | 100%
#
# openssl-1.1.1h       | 5.8 MB    |            |   0%
# openssl-1.1.1h       | 5.8 MB    |            |   1%
# openssl-1.1.1h       | 5.8 MB    | 4          |   5%
# openssl-1.1.1h       | 5.8 MB    | #          |  10%
# openssl-1.1.1h       | 5.8 MB    | #4         |  15%
# openssl-1.1.1h       | 5.8 MB    | #8         |  18%
# openssl-1.1.1h       | 5.8 MB    | ##2        |  23%
# openssl-1.1.1h       | 5.8 MB    | ##9        |  30%
# openssl-1.1.1h       | 5.8 MB    | ###4       |  34%
# openssl-1.1.1h       | 5.8 MB    | ###9       |  39%
# openssl-1.1.1h       | 5.8 MB    | ####4      |  45%
# openssl-1.1.1h       | 5.8 MB    | ####9      |  50%
# openssl-1.1.1h       | 5.8 MB    | #####4     |  55%
# openssl-1.1.1h       | 5.8 MB    | #####9     |  60%
# openssl-1.1.1h       | 5.8 MB    | ######4    |  64%
# openssl-1.1.1h       | 5.8 MB    | #######    |  70%
# openssl-1.1.1h       | 5.8 MB    | #######4   |  74%
# openssl-1.1.1h       | 5.8 MB    | ########   |  80%
# openssl-1.1.1h       | 5.8 MB    | ########4  |  85%
# openssl-1.1.1h       | 5.8 MB    | #########  |  90%
# openssl-1.1.1h       | 5.8 MB    | #########5 |  95%
# openssl-1.1.1h       | 5.8 MB    | ########## | 100%
# openssl-1.1.1h       | 5.8 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# seaborn installed

# %% [markdown]
# # Imports

# %%
#imports
import pandas as pd
import numpy as np
import os
import time
import tensorflow as tf
import tensorflow_hub as hub
import zipfile
#from html2text import HTML2Text
from tqdm import tqdm
import re
from sklearn.metrics import pairwise_distances
from sklearn.preprocessing import normalize
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#!conda install asmeurer html2text
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - html2text
#   - asmeurer
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/win-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/win-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#   - https://repo.anaconda.com/pkgs/msys2/win-64
#   - https://repo.anaconda.com/pkgs/msys2/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
from html2text import HTML2Text

# %% [markdown]
# # Set pandas print options
# This will improve readability of printed pandas dataframe.

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Set global Parameters
# Set your parameters here:
#
# data_path: In this path put the data you have downloaded with YouTube Data Tools.
# output_path: Tghe files generated in this notebook will be saved here.
#
# url_dict: URLs to models on Tensorflow hub are saved here. Other models are available there.
# model_type: Define which model you would like to use. Choose one from url_dict
#
# new_embeddings: If this is true, new embeddings will be generated and saved at output_path. Otherwise, embeddings are loaded from Disc.

# %%
data_path = './data/videoinfo__lslIyHo6zg_2020_12_01-14_50_09_comments.tab'
output_path = "./output/"

new_embeddings = True

url_dict = {
            'Transformer' : "https://tfhub.dev/google/universal-sentence-encoder-large/5",
            'DAN' : "https://tfhub.dev/google/universal-sentence-encoder/4",
            'Transformer_Multilingual': "https://tfhub.dev/google/universal-sentence-encoder-multilingual-large/3"
}

model_type = 'Transformer' #@param ['DAN','Transformer','Transformer_Multilingual']

# %% [markdown]
# ## Create output directory
# Try to create the directory defined by output_path

# %%
try:
   os.mkdir(output_path)
except OSError:
  print ("Creation of the directory %s failed" % output_path)
else:
  print ("Successfully created the directory %s " % output_path)
# Out:
# Successfully created the directory ./output/

# %% [markdown]
# # Load Data
# Load you data as a pandas dataframe

# %%
if new_embeddings:
    data = pd.read_csv(data_path,sep='\t',header=(0))
    data.head()

# %%
data.head()
# Out:
#                            id  replyCount  likeCount          publishedAt  \
# 0  Ugw2FmdFawVtLSxeqH14AaABAg         0.0          0  2020-11-14 11:29:17
# 1  UgyF6H8BEBmq_tjStV54AaABAg         0.0          0  2020-10-24 11:58:51
# 2  UgzZbPu3MawUcSKv0DN4AaABAg         0.0          0  2020-10-15 15:37:54
# 3  UgwknRpMHXakUdczG6l4AaABAg         0.0          0  2020-09-27 05:21:21
# 4  UgzQlz7VWrJamXgN6mF4AaABAg         0.0          0  2020-08-26 00:46:38
#
#        authorName  \
# 0     Dr Deadbeat
# 1     Bertie Blue
# 2         Spegger
# 3      SpraYeRS77
# 4  James Esselman
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       text  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             We had to watch this at university (in the UK) and discuss it as if the whole thing was fact
# 1                                                                                                                                                                                                                                         There is no context in science for hiding data. <br /><br />Genuine scientists would say &quot;we need to EXPLAIN the decline&quot; politically motivated cranks say &quot;hide the decline&quot; it is a matter of record the disgusting approach pseudoscience climate researchers took.<br /><br />What a waste of public monies this science bereft fraud of man made dangerous climate is, I might add the official censorship of skeptics by the BBC is reason enough to rescind the licence fee we shouldn&#39;t be paying for propaganda
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Again, no mention what on earth even is on the climate accord. People read it, it&#39;s a complete fraud! These people are professional liars and crooks, don&#39;t listen to their tyranny! BBC is an enemy of the people.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Was this piece sponsored by Al Gore?
# 4  That&#39;s right.... Us skeptics are really tricky. I admit it. What the BBC found out that they didn&#39;t reveal in this video is that us skeptics brainwashed Michael Mann and Phil Jones into acting like crooks through thought induction. We do this through channeling thought waves through a Ouija board. The average person when reading the Climategate E-mails would believe that Michael Mann and Phil Jones are dishonest crooks but they really aren&#39;t. It was our evil plan to make them look like totally dishonest, morally corrupt, climate assholes.... IT WAS US TRICKY CLIMATE CHANGE DENIERS AND OUR TRICKY TRICKINESS !.... I feel better now that I have come clean and I thank the always honest BBC for not relaying my criminal behavior to the police.
#
#             authorChannelId  \
# 0  UC_3nTK5UGdpuUyP2LpKPwUg
# 1  UCGyI5Vb4RPWfeWdBtlPgRbw
# 2  UCXwjB_hbrtvkziV9hSJXurw
# 3  UCCPAAc81GLDSYsAQI23af-w
# 4  UCdKu7f4_xvDk76cBywWEYqA
#
#                                           authorChannelUrl  isReply isReplyTo  \
# 0  http://www.youtube.com/channel/UC_3nTK5UGdpuUyP2LpKPwUg        0       NaN
# 1  http://www.youtube.com/channel/UCGyI5Vb4RPWfeWdBtlPgRbw        0       NaN
# 2  http://www.youtube.com/channel/UCXwjB_hbrtvkziV9hSJXurw        0       NaN
# 3  http://www.youtube.com/channel/UCCPAAc81GLDSYsAQI23af-w        0       NaN
# 4  http://www.youtube.com/channel/UCdKu7f4_xvDk76cBywWEYqA        0       NaN
#
#   isReplyToName
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %% [markdown]
# # Preprocessing
# Preprocess your data:
# - Drop empty rows
# - Drop unused columns

# %%
if new_embeddings:
    data = data.dropna(subset=['text', 'authorName']) # drop rows with no content
    data=data.drop(['id', 'replyCount','likeCount','authorChannelUrl','authorChannelId','isReplyTo','isReplyToName'],axis=1) # drop unused columns
    data.head()

# %% [markdown]
# - remove HTML-tags, links and usernames

# %%
if new_embeddings:
    # Remove HTML tags
    tqdm.pandas()
    h = HTML2Text()
    h.ignore_links = True
    data['cleaned'] = data['text'].progress_apply(lambda x: h.handle(x))
    print( "Removed HTML Tags.")

    # Remove links
    http_link_pattern = r'http\S+'
    bitly_link_pattern = r'bit.ly/\S+'
    data['cleaned'] = data['cleaned'].str.replace(http_link_pattern, '')
    data['cleaned'] = data['cleaned'].str.replace(bitly_link_pattern, '')
    print( "Removed Links.")

    # Remove user names
    keep_names = ["earth", "Tide", "Geologist", "A Person", "Titanic", "adventure", "Sun", "The United States Of America"] # user names we want to keep
    user_names = [name for name in data['authorName'].unique() if (len(name)> 3 and name not in keep_names)]
    data['cleaned'] = data['cleaned'].str.replace('|'.join(map(re.escape, user_names)), '')
    print( "Removed user names.")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 426/426 [00:00<00:00, 2349.81it/s]
# Removed HTML Tags.
# Removed Links.
# Removed user names.

# %% [markdown]
# # Save or Load preprocessed data
#
# Save your data afte preprocessing, or load preprocessed data from disc.

# %%
if new_embeddings:
  data.to_pickle(output_path+'data_preprocessed'+'.pkl')
else:
  data = pd.read_pickle(output_path+'data_preprocessed'+'.pkl')
data.head()
# Out:
#            publishedAt      authorName  \
# 0  2020-11-14 11:29:17     Dr Deadbeat
# 1  2020-10-24 11:58:51     Bertie Blue
# 2  2020-10-15 15:37:54         Spegger
# 3  2020-09-27 05:21:21      SpraYeRS77
# 4  2020-08-26 00:46:38  James Esselman
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       text  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             We had to watch this at university (in the UK) and discuss it as if the whole thing was fact
# 1                                                                                                                                                                                                                                         There is no context in science for hiding data. <br /><br />Genuine scientists would say &quot;we need to EXPLAIN the decline&quot; politically motivated cranks say &quot;hide the decline&quot; it is a matter of record the disgusting approach pseudoscience climate researchers took.<br /><br />What a waste of public monies this science bereft fraud of man made dangerous climate is, I might add the official censorship of skeptics by the BBC is reason enough to rescind the licence fee we shouldn&#39;t be paying for propaganda
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Again, no mention what on earth even is on the climate accord. People read it, it&#39;s a complete fraud! These people are professional liars and crooks, don&#39;t listen to their tyranny! BBC is an enemy of the people.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Was this piece sponsored by Al Gore?
# 4  That&#39;s right.... Us skeptics are really tricky. I admit it. What the BBC found out that they didn&#39;t reveal in this video is that us skeptics brainwashed Michael Mann and Phil Jones into acting like crooks through thought induction. We do this through channeling thought waves through a Ouija board. The average person when reading the Climategate E-mails would believe that Michael Mann and Phil Jones are dishonest crooks but they really aren&#39;t. It was our evil plan to make them look like totally dishonest, morally corrupt, climate assholes.... IT WAS US TRICKY CLIMATE CHANGE DENIERS AND OUR TRICKY TRICKINESS !.... I feel better now that I have come clean and I thank the always honest BBC for not relaying my criminal behavior to the police.
#
#    isReply  \
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     cleaned
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         We had to watch this at university (in the UK) and discuss it as if the whole\nthing was fact\n\n
# 1                                                                                                                                                                                                                                                                   There is no context in science for hiding data.  \n  \nGenuine scientists would say "we need to EXPLAIN the decline" politically\nmotivated cranks say "hide the decline" it is a matter of record the\ndisgusting approach pseudoscience climate researchers took.  \n  \nWhat a waste of public monies this science bereft fraud of man made dangerous\nclimate is, I might add the official censorship of skeptics by the BBC is\nreason enough to rescind the licence fee we shouldn't be paying for propaganda\n\n
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Again, no mention what on earth even is on the climate accord. People read it,\nit's a complete fraud! These people are professional liars and crooks, don't\nlisten to their tyranny! BBC is an enemy of the people.\n\n
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Was this piece sponsored by Al Gore?\n\n
# 4  That's right.... Us skeptics are really tricky. I admit it. What the BBC found\nout that they didn't reveal in this video is that us skeptics brainwashed\nMichael Mann and Phil Jones into acting like crooks through thought induction.\nWe do this through channeling thought waves through a Ouija board. The average\nperson when reading the Climategate E-mails would believe that Michael Mann\nand Phil Jones are dishonest crooks but they really aren't. It was our evil\nplan to make them look like totally dishonest, morally corrupt, climate\nassholes.... IT WAS US TRICKY CLIMATE CHANGE DENIERS AND OUR TRICKY TRICKINESS\n!.... I feel better now that I have come clean and I thank the always honest\nBBC for not relaying my criminal behavior to the police.\n\n

# %% [markdown]
# # Produce Text Embeddings with Universal Sentence Encoder

# %% [markdown]
# ## Load Model
# Load the model from TF-hub

# %%
hub_url = url_dict[model_type]
if new_embeddings:
  print("Loading model. This will take some time...")
  embed = hub.load(hub_url)
# Out:
# Loading model. This will take some time...

# %% [markdown]
# ## Embed Documents
# Produce embeddings of your documents.

# %%
if new_embeddings:
    for k,g in data.groupby(np.arange(len(data))//200):
        if k == 0:
            embeddings = embed(g['cleaned'])
        else:
            embeddings_new = embed(g['cleaned'])
            embeddings = tf.concat(values=[embeddings,embeddings_new],axis = 0)
            print(k , end =" ")
    print("The embeddings vector is of fixed length {}".format(embeddings.shape[1]))

    np.save(output_path+'/embeddings'+model_type+'.npy', embeddings, allow_pickle=True, fix_imports=True)
else:
    embeddings = np.load(output_path+'/embeddings'+model_type+'.npy', mmap_mode=None, allow_pickle=False, fix_imports=True, encoding='ASCII')

embeddings.shape
# Out:
# 1 2 The embeddings vector is of fixed length 512
# TensorShape([426, 512])

# %% [markdown]
# ## Calculate Similarity Matrix with angular distance
#
# 'Following Cer et al. (2018), we first compute
# the sentence embeddings u, v for an STS sentence
# pair, and then score the sentence pair similarity
# based on the angular distance between the two
# embedding vectors  d = − arccos (uv/||u|| ||v||).'

# %%
from sklearn.metrics.pairwise import cosine_similarity
def cos_sim(input_vectors):
    similarity = cosine_similarity(input_vectors)
    return similarity
cosine_similarity_matrix = cos_sim(np.array(embeddings))
print(cosine_similarity_matrix)
# Out:
# [[ 1.0000001   0.17476888  0.2832076  ...  0.12817577  0.1223225
#    0.08649181]
#  [ 0.17476888  0.99999994  0.44149414 ...  0.1828466   0.2308078
#   -0.03353097]
#  [ 0.2832076   0.44149414  1.0000002  ...  0.2704749   0.3316369
#   -0.0141933 ]
#  ...
#  [ 0.12817577  0.1828466   0.2704749  ...  1.          0.5238452
#    0.02373179]
#  [ 0.1223225   0.2308078   0.3316369  ...  0.5238452   1.0000002
#    0.03558647]
#  [ 0.08649181 -0.03353097 -0.0141933  ...  0.02373179  0.03558647
#    0.99999994]]

# %% [markdown]
# # Plots Similarity
# Plot and print a heat map showing the semantic contextual similarity between comments.

# %%
import seaborn as sns
def plot_similarity(labels, features, rotation):
  corr = np.inner(features, features)
  sns.set(font_scale=1.2)
  g = sns.heatmap(
      corr,
      xticklabels=labels,
      yticklabels=labels,
      vmin=0,
      vmax=1,
      cmap="YlOrRd")
  g.set_xticklabels(labels, rotation=rotation)
  g.set_title("Semantic Textual Similarity")

num_samples = 5
off_set = 100

plot_similarity(data.iloc[off_set:off_set+num_samples]['cleaned'], embeddings[off_set:off_set+num_samples], 90)

# %% [markdown]
# # Show neighbours of a comment
# Define which comment to analyze

# %%
comment_index = 324
comment = data["cleaned"][comment_index]
comment_list = data["cleaned"].tolist()
print(comment)
# Out:
#  Thank you for your kind words. Its tricky at times. I was listening
# to Morrissey the other night. He’s is such a kind soul who is vilified by so
# many people theses days. I cant help but feel they are wrong about him.

# %% [markdown]
# Print similar comments.

# %%
def get_top_similar(sentence, sentence_list, similarity_matrix, topN):
    # find the index of sentence in list
    index = sentence_list.index(sentence)
    # get the corresponding row in similarity matrix
    similarity_row = np.array(similarity_matrix[index, :])
    # get the indices of top similar
    indices = similarity_row.argsort()[-topN:][::-1]
    return [sentence_list[i] for i in indices]


for i, value in enumerate(get_top_similar(comment, comment_list, cosine_similarity_matrix, 20)):
  print("Top similar comment {}: {}".format(i+1, value))
# Out:
# Top similar comment 1:  Thank you for your kind words. Its tricky at times. I was listening
# to Morrissey the other night. He’s is such a kind soul who is vilified by so
# many people theses days. I cant help but feel they are wrong about him.
#
#
# Top similar comment 2: Then again it wouldn’t be like Travis Bickle to be embittered in anyway and
# instead of engaging with public issues like this with an open and reasonable
# mind just go about thinking your so righteous and heroic for being a cynic on
# the sideline
#
#
# Top similar comment 3: @ And many more people who are much better informed than you or
# I disagree with those people and you. Sorry to beak it to you, but the best
# analysis of the best information proves you wrong. I'm not an expert on
# anything, sadly. But at least I have the humility to accept the best
# information available..
#
#
# Top similar comment 4: Well said. I think it fair to add that I'm on the opposite side of the
# spectrum to the moron on the street. the issues are complex, indeed very
# complex. Also too many "scientists" who have nothing to do with Cimatology are
# weighing in too often. Leave the facts to the experts please.
#
#
# Top similar comment 5: There is a lot of money and political capital at stake in being wrong about
# the supposed warming and human contribution to that. It works both ways.
# Popular belief is all the rage. But the truth is somewhat more difficult to
# know. Read my main post today perhaps.
#
#
# Top similar comment 6: Thank you BBC, for a horrible moment I thought the 'climate emergency' was an
# absolute con.
#
#
# Top similar comment 7:  funny how the bloke he interviewed admitted his lies, yep nice to see
# Andrew Neil in action making the nobs look like overpaid stupid non scientific
# decision makers 🤪
#
#
# Top similar comment 8: Just been debating some of the extinction rebellion lot, and they won't accept
# that over population is an issue. Their idea is that we all become vegans and
# stop enjoying life, if we all do that then the population can double without
# climate problems, they are quite mad.
#
#
# Top similar comment 9: You’ve made some stupid comment somewhere that I can’t be bothered to find. I
# am not insulting anyone. There are an astronomical number of cretins, morons
# and pig-ignorant f**kwits posting response to this clip. This is not an
# insult. This is a matter of fact. Given what you’ve posted above, you fit in
# that bracket too, fuc**wit,
#
#
# Top similar comment 10:  I know all the measurements thanks and it’s very easy to debate
# people like yourself because you have no idea of what basic scientific
# measurement is, when your told measurements that cannot be wrong because they
# are after the event took place you just deny them like a child 👶🍼
#
#
# Top similar comment 11: Lol to these Cretens. Thank you for giving it straight!!
#
#
# Top similar comment 12:  you're entitled to your opinion, but many people much smarter
# than you and I disagree with you. Sorry to have to break it to you.
#
#
# Top similar comment 13: @ I will wish you luck. I had 4 kids myself. Fortunately they
# turned out well. From reading what you say, I see you have an open mind and
# think yours will too.
#
#
# Top similar comment 14:  You are a good man. If the world had more folks like you it would be a
# better place. I have just read through your very comprehensive answer to my
# question. I will read through again when I have more time. I am just about to
# try and put 4 kids between the ages of 4 and 13 to bed. Wish me luck.
#
#
# Top similar comment 15: @Jack Richardson yes, I'm a climatogist, thanks for letting me know.
#
#
# Top similar comment 16:  You idiot. I am not labeling anything or anyone who has the vaguest
# understanding of climate science in any way. The deniers, on the other hand,
# are people who do not understand the physics or the history of climate change.
# Do tell, how long have we known that CO2 is changing the atmosphere. I bet you
# do not know.
#
#
# Top similar comment 17: Michael Mann is a fraud.
#
#
#
# star-michael-mann-courts-legal-disaster/amp/
#
#
# global-warming-scientist-ordered-to-pay-opponents-legal-costs-in-libel-suit
#
#
# mails-rock-the-global-warming-debate/#187d4b2227ba
#
#
# Top similar comment 18:  Crap. Andrew Neil is so full of himself that he can’t begin to interview
# in an even-handed way.
#
#
# Top similar comment 19: Michael Mann is a FRAUD. That's why the Democrats love him.
#
#
# Top similar comment 20: Psy op cover up ! Anybody who believes the BBC needs to fact check for
# themselves like I did , there using children for guilty emotion and forget
# about facts . They did the same with WMD'S and Saville!
# And the worst thing is most actually believe them ! WAKE UP!
